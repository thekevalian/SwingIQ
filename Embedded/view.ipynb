# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('SAMPLE47.CSV')
df['time (ms)'] = df['time (ms)'] - df['time (ms)'].min()
df.drop(columns=['temperature (C)'], inplace=True)
df
# Out:
#       time (ms)  Ax (m/s^2)    Ay     Az  Gx (rads/s)    Gy    Gz
# 0             0       -7.05  1.36   7.23         0.56 -0.19  0.16
# 1             8       -7.16  1.60   7.35         0.51 -0.19  0.15
# 2            10       -7.42  1.90   7.79         0.41 -0.20  0.15
# 3            16       -7.48  2.23   8.30         0.27 -0.21  0.14
# 4            18       -7.27  2.57   8.48         0.10 -0.21  0.14
# ...         ...         ...   ...    ...          ...   ...   ...
# 1249       7783        1.36 -0.89  -9.57         0.00 -0.09 -0.11
# 1250       7785        1.45 -0.78  -9.82         0.03 -0.09 -0.11
# 1251       7792        1.52 -0.53 -10.18         0.06 -0.08 -0.11
# 1252       7794        1.53 -0.45 -10.18         0.09 -0.07 -0.11
# 1253       7801        1.55 -0.35 -10.29         0.09 -0.06 -0.10
#
# [1254 rows x 7 columns]

# %%
samples_times = (df['time (ms)'] - df['time (ms)'].shift(-1))[:-1]
plt.hist(samples_times, bins=100)
plt.ylim(0, 100)
# Out:
# (0.0, 100.0)

# %%
plt.figure(figsize=(12,8))
for column in df.columns:
    if column != "time (ms)":
        plt.scatter(df['time (ms)'], df[column], label=column, s=3)
plt.legend()
plt.show()
